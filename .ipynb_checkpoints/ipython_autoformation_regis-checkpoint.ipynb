# %% [markdown]
# autoformation pandas Régis sur données eutrophisation melina

# %%
print 'hello'
# Out:
# hello

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### POur mémoire, récupérer les attributs d'une couche dans QGIS

# %% [raw]
# # colonnes/champs de la couche
# champs = couche.pendingFields()
# # nom des colonnes/champs
# nom_champs = [champ.name() for champ in champs]
# for elem in couche.getFeatures():
# # attributs
# attrib = dict(zip(nom_champs, elem.attributes()))
# print attrib
# {u'nom': u'Xhonneux', u'direction': 67, u'id': 1, u'statut': u'normale'}
# {u'nom': u'Moulin', u'direction': 80, u'id': 2, u'statut': u'chevauch'}

# %% [markdown]
# # creation d'objet

# %% [markdown]
# ### création d'une série, indexation numérique par défaut

# %%
s= pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %% [markdown]
# ### création d'un tableau de date dataframe avec index sur date et colonnes étiquettée (via un tableau numPy)

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.013080 -0.676959  0.026400 -0.500027
# 2013-01-02 -0.454551  1.112689  0.495159  0.234503
# 2013-01-03  1.137343 -1.458859  0.192225  0.000153
# 2013-01-04  1.546996  0.562787  0.247963  2.365857
# 2013-01-05 -0.511529  0.634469  0.955747 -0.074090
# 2013-01-06 -0.099451  1.015992 -0.809770 -1.104470

# %% [raw]
# autre méthode par dico

# %%
df2= pd.DataFrame({'A' : 1.,
                   'B' : pd.Timestamp('20130102'),
                   'C' : pd.Series(2,index=list(range(4)),dtype='float32'),
                   'D' : np.array([3] * 4,dtype='int32'),
                   'E' : pd.Categorical(["test","train","test","train"]),
                   'F' : 'foo' })

# %%
df2
# Out:
#    A          B  C  D      E    F
# 0  1 2013-01-02  2  3   test  foo
# 1  1 2013-01-02  2  3  train  foo
# 2  1 2013-01-02  2  3   test  foo
# 3  1 2013-01-02  2  3  train  foo

# %% [raw]
# recuperer les types

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [raw]
# autocomplétion de noms de champs et de fonctions avec tab

# %%
df.abs
# Out:
# <bound method DataFrame.abs of                    A         B         C         D
# 2013-01-01  0.013080 -0.676959  0.026400 -0.500027
# 2013-01-02 -0.454551  1.112689  0.495159  0.234503
# 2013-01-03  1.137343 -1.458859  0.192225  0.000153
# 2013-01-04  1.546996  0.562787  0.247963  2.365857
# 2013-01-05 -0.511529  0.634469  0.955747 -0.074090
# 2013-01-06 -0.099451  1.015992 -0.809770 -1.104470>

# %%
df.A
# Out:
# 2013-01-01    0.013080
# 2013-01-02   -0.454551
# 2013-01-03    1.137343
# 2013-01-04    1.546996
# 2013-01-05   -0.511529
# 2013-01-06   -0.099451
# Freq: D, Name: A, dtype: float64

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.013080 -0.676959  0.026400 -0.500027
# 2013-01-02 -0.454551  1.112689  0.495159  0.234503
# 2013-01-03  1.137343 -1.458859  0.192225  0.000153
# 2013-01-04  1.546996  0.562787  0.247963  2.365857
# 2013-01-05 -0.511529  0.634469  0.955747 -0.074090

# %%
df.tail(2)
# Out:
#                    A         B         C        D
# 2013-01-05 -0.511529  0.634469  0.955747 -0.07409
# 2013-01-06 -0.099451  1.015992 -0.809770 -1.10447

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2013-01-01, ..., 2013-01-06]
# Length: 6, Freq: D, Timezone: None

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.values
# Out:
# array([[  1.30799640e-02,  -6.76959077e-01,   2.63999624e-02,
#          -5.00026836e-01],
#        [ -4.54550986e-01,   1.11268927e+00,   4.95158541e-01,
#           2.34502617e-01],
#        [  1.13734280e+00,  -1.45885910e+00,   1.92224551e-01,
#           1.53297313e-04],
#        [  1.54699580e+00,   5.62787118e-01,   2.47962966e-01,
#           2.36585746e+00],
#        [ -5.11528595e-01,   6.34468502e-01,   9.55746871e-01,
#          -7.40899268e-02],
#        [ -9.94507156e-02,   1.01599241e+00,  -8.09770145e-01,
#          -1.10447029e+00]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.271981  0.198353  0.184620  0.153654
# std    0.862698  1.033448  0.584634  1.182031
# min   -0.511529 -1.458859 -0.809770 -1.104470
# 25%   -0.365776 -0.367023  0.067856 -0.393543
# 50%   -0.043185  0.598628  0.220094 -0.036968
# 75%    0.856277  0.920611  0.433360  0.175915
# max    1.546996  1.112689  0.955747  2.365857

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.013080   -0.454551    1.137343    1.546996   -0.511529   -0.099451
# B   -0.676959    1.112689   -1.458859    0.562787    0.634469    1.015992
# C    0.026400    0.495159    0.192225    0.247963    0.955747   -0.809770
# D   -0.500027    0.234503    0.000153    2.365857   -0.074090   -1.104470

# %% [markdown]
# # Essai sur les données qualité hébergées sur postgres

# %% [markdown]
# ## Connection postgres

# %%
import psycopg2
import sys
import pprint


conn_string = "host='pgpool' dbname='refgeo2' user='visu' password='visu'"
 
# print the connection string we will use to connect
print "Connecting to database\n	->%s" % (conn_string)

# get a connection, if a connect cannot be made an exception will be raised here
conn = psycopg2.connect(conn_string)

# conn.cursor will return a cursor object, you can use this cursor to perform queries
cursor = conn.cursor()
print "Connected!\n"
# Out:
# Connecting to database
# 	->host='pgpool' dbname='refgeo2' user='visu' password='visu'
# Connected!

# %% [markdown]
# ## Execution d'un select
# http://nbviewer.ipython.org/github/jvns/pandas-cookbook/blob/master/cookbook/Chapter%209%20-%20Loading%20data%20from%20SQL%20databases.ipynb

# %% [markdown]
# ## Select dans dataframe panda

# %%
eutroDf = pd.read_sql("SELECT dateheure, code_sandre_stq code_stq, resultat_l_analyse result, unite, libunite, code_remarque FROM temp.test_data_qual_perf WHERE code_parametre = 1340 ", conn, index_col='dateheure', parse_dates= 'dateheure' )

# %%
eutroDf
# Out:
#             code_stq  result  unite                          libunite  \
# dateheure
# 2008-01-10  05000100    6.00    173  milligramme de nitrate par litre
# 2008-04-02  05000100   11.00    173  milligramme de nitrate par litre
# 2008-06-11  05000100   33.00    173  milligramme de nitrate par litre
# 2008-08-08  05000100    2.00    173  milligramme de nitrate par litre
# 2008-09-08  05000100   15.00    173  milligramme de nitrate par litre
# 2008-11-12  05000100   46.00    173  milligramme de nitrate par litre
# 2009-01-30  05000100   41.00    173  milligramme de nitrate par litre
# 2009-03-27  05000100    8.00    173  milligramme de nitrate par litre
# 2009-06-12  05000100    8.00    173  milligramme de nitrate par litre
# 2009-08-13  05000100    1.00    173  milligramme de nitrate par litre
# 2009-09-11  05000100    1.00    173  milligramme de nitrate par litre
# 2009-11-27  05000100    2.00    173  milligramme de nitrate par litre
# 2010-01-22  05000100   70.00    173  milligramme de nitrate par litre
# 2010-03-17  05000100   46.00    173  milligramme de nitrate par litre
# 2010-06-11  05000100    5.00    173  milligramme de nitrate par litre
# 2010-08-09  05000100   12.00    173  milligramme de nitrate par litre
# 2010-09-03  05000100    1.00    173  milligramme de nitrate par litre
# 2010-11-29  05000100   80.00    173  milligramme de nitrate par litre
# 2011-01-14  05000100   48.00    173  milligramme de nitrate par litre
# 2011-03-14  05000100   75.00    173  milligramme de nitrate par litre
# 2011-06-23  05000100    1.00    173  milligramme de nitrate par litre
# 2011-08-01  05000100    1.00    173  milligramme de nitrate par litre
# 2011-09-12  05000100    1.00    173  milligramme de nitrate par litre
# 2011-11-28  05000100    1.00    173  milligramme de nitrate par litre
# 2008-01-10  05000110    3.00    173  milligramme de nitrate par litre
# 2008-01-21  05000110    3.90    173  milligramme de nitrate par litre
# 2008-03-17  05000110   14.60    173  milligramme de nitrate par litre
# 2008-04-02  05000110    1.00    173  milligramme de nitrate par litre
# 2008-05-19  05000110   33.80    173  milligramme de nitrate par litre
# 2008-06-11  05000110    5.00    173  milligramme de nitrate par litre
# ...              ...     ...    ...                               ...
# 2008-01-24  05238500    3.80    173  milligramme de nitrate par litre
# 2008-03-20  05238500    3.00    173  milligramme de nitrate par litre
# 2008-05-22  05238500    0.10    173  milligramme de nitrate par litre
# 2008-07-24  05238500    1.90    173  milligramme de nitrate par litre
# 2008-09-18  05238500    3.80    173  milligramme de nitrate par litre
# 2008-11-20  05238500    3.20    173  milligramme de nitrate par litre
# 2009-01-22  05238500    4.69    173  milligramme de nitrate par litre
# 2009-03-19  05238500    2.08    173  milligramme de nitrate par litre
# 2009-05-14  05238500    3.55    173  milligramme de nitrate par litre
# 2009-07-23  05238500    1.93    173  milligramme de nitrate par litre
# 2009-09-17  05238500    3.69    173  milligramme de nitrate par litre
# 2009-11-19  05238500    3.71    173  milligramme de nitrate par litre
# 2010-09-02  05238500    2.33    173  milligramme de nitrate par litre
# 2010-09-20  05238500    3.31    173  milligramme de nitrate par litre
# 2010-10-14  05238500    4.52    173  milligramme de nitrate par litre
# 2010-11-02  05238500   12.80    173  milligramme de nitrate par litre
# 2010-11-22  05238500    4.79    173  milligramme de nitrate par litre
# 2010-12-13  05238500    3.58    173  milligramme de nitrate par litre
# 2011-01-24  05238500    2.87    173  milligramme de nitrate par litre
# 2011-03-21  05238500    2.70    173  milligramme de nitrate par litre
# 2011-05-16  05238500    3.03    173  milligramme de nitrate par litre
# 2011-07-26  05238500    2.90    173  milligramme de nitrate par litre
# 2011-09-20  05238500    3.53    173  milligramme de nitrate par litre
# 2011-11-22  05238500    3.32    173  milligramme de nitrate par litre
# 2012-01-23  05238500    3.10    173  milligramme de nitrate par litre
# 2012-03-19  05238500    1.95    173  milligramme de nitrate par litre
# 2012-05-21  05238500    3.39    173  milligramme de nitrate par litre
# 2012-07-23  05238500    2.13    173  milligramme de nitrate par litre
# 2012-09-17  05238500    2.83    173  milligramme de nitrate par litre
# 2012-11-21  05238500    3.54    173  milligramme de nitrate par litre
#
#             code_remarque
# dateheure
# 2008-01-10              1
# 2008-04-02              1
# 2008-06-11              1
# 2008-08-08              1
# 2008-09-08              1
# 2008-11-12              1
# 2009-01-30              1
# 2009-03-27              1
# 2009-06-12              1
# 2009-08-13             10
# 2009-09-11             10
# 2009-11-27              1
# 2010-01-22              1
# 2010-03-17              1
# 2010-06-11              1
# 2010-08-09              1
# 2010-09-03             10
# 2010-11-29              1
# 2011-01-14              1
# 2011-03-14              1
# 2011-06-23             10
# 2011-08-01             10
# 2011-09-12             10
# 2011-11-28             10
# 2008-01-10              1
# 2008-01-21              1
# 2008-03-17              1
# 2008-04-02             10
# 2008-05-19              1
# 2008-06-11              1
# ...                   ...
# 2008-01-24              1
# 2008-03-20              1
# 2008-05-22             10
# 2008-07-24              1
# 2008-09-18              1
# 2008-11-20              1
# 2009-01-22              1
# 2009-03-19              1
# 2009-05-14              1
# 2009-07-23              1
# 2009-09-17              1
# 2009-11-19              1
# 2010-09-02              1
# 2010-09-20              1
# 2010-10-14              1
# 2010-11-02              1
# 2010-11-22              1
# 2010-12-13              1
# 2011-01-24              1
# 2011-03-21              1
# 2011-05-16              1
# 2011-07-26              1
# 2011-09-20              1
# 2011-11-22              1
# 2012-01-23              1
# 2012-03-19              1
# 2012-05-21              1
# 2012-07-23              1
# 2012-09-17              1
# 2012-11-21              1
#
# [42707 rows x 5 columns]

# %%
eutroDf.describe()
# Out:
#              result  unite  code_remarque
# count  42707.000000  42707   42707.000000
# mean      11.855853    173       1.264898
# std       13.207463      0       1.521172
# min        0.030000    173       1.000000
# 25%        3.260000    173       1.000000
# 50%        6.700000    173       1.000000
# 75%       16.000000    173       1.000000
# max      514.000000    173      10.000000

# %%
eutroDf.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2008-01-10, ..., 2012-11-21]
# Length: 42707, Freq: None, Timezone: None

# %%
eutroDf.columns
# Out:
# Index([u'code_stq', u'result', u'unite', u'libunite', u'code_remarque'], dtype='object')

# %% [markdown]
# ## Exploration statistique

# %%
eutroDf['result'].value_counts().sort
# Out:
# <bound method Series.sort of 1     1304
# 4      690
# 3      687
# 2      676
# 5      632
# 6      503
# 11     437
# 7      426
# 12     375
# 10     373
# 13     359
# 8      348
# 14     304
# 9      294
# 16     291
# ...
# 0.340      1
# 0.350      1
# 103.000    1
# 102.000    1
# 0.868      1
# 0.301      1
# 65.200     1
# 107.000    1
# 83.900     1
# 106.000    1
# 15.790     1
# 60.300     1
# 55.110     1
# 114.000    1
# 0.666      1
# Length: 1680, dtype: int64>

# %% [raw]
# group by year , trimestre

# %%
eutroDf.resample('1A', how=['mean', 'median'])
# Out:
#                result        unite        code_remarque
#                  mean median  mean median          mean median
# dateheure
# 2008-12-31  11.966386   7.20   173    173      1.232714      1
# 2009-12-31  11.756257   7.00   173    173      1.321143      1
# 2010-12-31  12.323716   6.90   173    173      1.244104      1
# 2011-12-31  11.415908   6.30   173    173      1.324207      1
# 2012-12-31  11.923275   6.19   173    173      1.214215      1

# %%
eutroDf.resample('3M', how='mean')
# Out:
#                result  unite  code_remarque
# dateheure
# 2008-01-31  16.658692    173       1.120357
# 2008-04-30  12.385086    173       1.174820
# 2008-07-31  12.263880    173       1.234217
# 2008-10-31   8.535435    173       1.383784
# 2009-01-31  13.343585    173       1.145081
# 2009-04-30  13.793259    173       1.147974
# 2009-07-31  11.406303    173       1.329457
# 2009-10-31   7.548780    173       1.608174
# 2010-01-31  15.377359    173       1.207942
# 2010-04-30  16.947115    173       1.072934
# 2010-07-31  14.957015    173       1.401786
# 2010-10-31   9.173494    173       1.303299
# 2011-01-31  14.491480    173       1.153685
# 2011-04-30  14.859507    173       1.098738
# 2011-07-31  11.100038    173       1.271823
# 2011-10-31   7.696701    173       1.583489
# 2012-01-31  12.060134    173       1.335646
# 2012-04-30  11.572674    173       1.146789
# 2012-07-31  13.586297    173       1.159140
# 2012-10-31   8.503318    173       1.364286
# 2013-01-31  12.625434    173       1.241026

# %% [raw]
# Plot ? module spécifique matplotlib pour notebook

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
moy_trimestre = eutroDf['result'].resample('3M', how='mean')

# %%
moy_trimestre.plot()

# %%
stats_trimestre = eutroDf['result'].resample('2M', how=['mean', np.min,np.median])

# %%
stats_trimestre.plot()

# %% [raw]
# Travail sur 4 variables, merge de 4 lots de données?

# %%
dfNP = pd.read_sql("select nitr.dateheure, nitr.code_stq, nitr.result as result_nitr, phos.result as result_phos FROM (SELECT distinct ON (dateheure, code_sandre_stq , code_parametre) dateheure, code_sandre_stq code_stq, code_parametre, resultat_l_analyse result FROM temp.test_data_qual_perf WHERE (code_parametre = 1340) order by code_stq) nitr JOIN (SELECT distinct ON (dateheure, code_sandre_stq , code_parametre) dateheure, code_sandre_stq code_stq, code_parametre, resultat_l_analyse result FROM temp.test_data_qual_perf WHERE (code_parametre = 1350)) phos ON (nitr.dateheure=phos.dateheure and nitr.code_stq = phos.code_stq)", conn, index_col ='dateheure', parse_dates= 'dateheure')

# %%
dfNP
# Out:
#             code_stq  result_nitr  result_phos
# dateheure
# 2008-01-21  05000110         3.90        0.250
# 2008-03-17  05000110        14.60        0.200
# 2008-05-19  05000110        33.80        0.070
# 2008-07-21  05000110        25.20        0.230
# 2008-09-15  05000110        15.80        0.120
# 2008-11-18  05000110         0.90        0.650
# 2009-01-19  05000110        43.50        0.500
# 2009-03-19  05000110        43.80        0.200
# 2009-05-11  05000110        28.90        0.130
# 2009-07-20  05000110        10.30        0.210
# 2009-09-14  05000110         6.10        0.210
# 2009-11-16  05000110        15.70        0.100
# 2010-09-02  05000110        10.90        0.150
# 2010-09-22  05000110        10.30        0.220
# 2010-10-13  05000110         8.30        0.210
# 2010-11-04  05000110        14.40        0.095
# 2010-11-25  05000110         1.60        0.330
# 2010-12-15  05000110         0.60        0.180
# 2011-01-26  05000110         2.30        0.150
# 2011-03-21  05000110        43.20        0.078
# 2011-05-19  05000110        22.40        0.150
# 2011-07-25  05000110         9.90        0.069
# 2011-09-19  05000110        15.20        0.089
# 2011-11-21  05000110        30.20        0.050
# 2012-01-25  05000110         2.60        0.150
# 2012-03-19  05000110        33.10        0.055
# 2012-05-23  05000110         0.50        0.210
# 2012-07-24  05000110        24.90        0.046
# 2012-09-19  05000110         7.60        0.100
# 2012-11-19  05000110         0.20        0.230
# ...              ...          ...          ...
# 2008-01-24  05238500         3.80        0.020
# 2008-03-20  05238500         3.00        0.020
# 2008-05-22  05238500         0.10        0.020
# 2008-07-24  05238500         1.90        0.040
# 2008-09-18  05238500         3.80        0.040
# 2008-11-20  05238500         3.20        0.020
# 2009-01-22  05238500         4.69        0.020
# 2009-03-19  05238500         2.08        0.020
# 2009-05-14  05238500         3.55        0.090
# 2009-07-23  05238500         1.93        0.020
# 2009-09-17  05238500         3.69        0.040
# 2009-11-19  05238500         3.71        0.020
# 2010-09-02  05238500         2.33        0.030
# 2010-09-20  05238500         3.31        0.040
# 2010-10-14  05238500         4.52        0.140
# 2010-11-02  05238500        12.80        0.070
# 2010-11-22  05238500         4.79        0.050
# 2010-12-13  05238500         3.58        0.020
# 2011-01-24  05238500         2.87        0.030
# 2011-03-21  05238500         2.70        0.020
# 2011-05-16  05238500         3.03        0.050
# 2011-07-26  05238500         2.90        0.080
# 2011-09-20  05238500         3.53        0.050
# 2011-11-22  05238500         3.32        0.030
# 2012-01-23  05238500         3.10        0.020
# 2012-03-19  05238500         1.95        0.010
# 2012-05-21  05238500         3.39        0.080
# 2012-07-23  05238500         2.13        0.040
# 2012-09-17  05238500         2.83        0.070
# 2012-11-21  05238500         3.54        0.030
#
# [41359 rows x 3 columns]

# %%
dfNP.plot(kind='box')

# %%
dfNP['result_phos'].plot(kind='box')

# %%
dfNP.resample('1M', how=['mean', np.min,np.median]).plot(kind='line',logy=False, subplots=True, figsize=(15,10))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x000000000E83A710>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000E777A90>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000E764978>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000E71DDA0>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000E6BEA58>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000E6A8080>], dtype=object)

# %%
dfNP.resample('1M', how='mean').plot(kind='line', logy=False, subplots=True, figsize=(15,10))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x0000000010C95B38>,
#        <matplotlib.axes.AxesSubplot object at 0x0000000010CACF60>], dtype=object)

# %%
pd.scatter_matrix(dfNP, alpha=0.2, figsize=(6,6), diagonal='kde')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x00000000114B8550>,
#         <matplotlib.axes.AxesSubplot object at 0x0000000011283240>],
#        [<matplotlib.axes.AxesSubplot object at 0x000000001119E8D0>,
#         <matplotlib.axes.AxesSubplot object at 0x0000000011123C50>]], dtype=object)

# %% [raw]
# Conclusion > distribution logarithique centrée sur les faibles valeurs > normaliser en log

# %%
dfNP1mois=dfNP.resample('1M', how='mean')

# %%
dfNP1mois.plot(kind='scatter', x='result_nitr', y='result_phos', s=dfNP1mois['result_nitr']*100, logy=False, figsize=(15,10), alpha=0.2)

# %%
from pandas.tools.plotting import lag_plot

# %%
lag_plot(dfNP1mois['result_phos'])

# %% [markdown]
# ### Essais de construction de dataframe from QGIS

# %%
dictRow1 = {u'nom': u'Xhonneux', u'direction': 67, u'id': 1, u'statut': u'normale'}

# %%
dictRow2 = {u'nom': u'Moulin', u'direction': 80, u'id': 2, u'statut': u'chevauch'}

# %%
dictTable = {'row1':{'nom': 'Xhonneux', 'direction': 67, 'id': 1, 'statut': 'normale'}}

# %%
dictTable['row2'] = dictRow2

# %%
dfFromDic = pd.DataFrame.from_dict(dictTable, orient='index')

# %%
dfFromDic
# Out:
#            nom  direction  id    statut
# row1  Xhonneux         67   1   normale
# row2    Moulin         80   2  chevauch

# %% [markdown]
# ##### Passer par des listes pour construire le dataframe evite la redondance de données.
